# %% [markdown]
# Download backfill data using Databricks, alternative to ADF

# %%
import sys
import os
import urllib.request
import shutil

root = os.path.abspath(os.path.join(os.getcwd(), "../.."))

if root not in sys.path:
    sys.path.append(root)

from modules.data_loader.file_downloader import download_file

# %%
dates_to_process = ['2025-05', '2025-06', '2025-07', '2025-08', '2025-09', '2025-10']

for date in dates_to_process:
    # url to download the files
    url = f"https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_{date}.parquet"

    # local directory date wise
    dir_path = f"/Volumes/nyc-taxi/00_landing/data_sources/nyctaxi_green/{date}"

    # Full path for the file
    local_path = f"{dir_path}/green_tripdata_{date}.parquet"

    download_file(url, dir_path, local_path)
